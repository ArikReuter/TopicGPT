# %%
# %load_ext autoreload
# %autoreload 2

# %%
import Clustering
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
# Out:
# c:\Users\arik_\anaconda3\envs\llm_sem\Lib\site-packages\umap\distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# c:\Users\arik_\anaconda3\envs\llm_sem\Lib\site-packages\umap\distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
data = pickle.load(open("../../Data/Emebeddings/embeddings_reuters_raw.pkl", "rb"))
embeddings = data['embeddings']
texts = data["corpus"]

# %%
clustering = Clustering.Clustering_and_DimRed()
reduced_embeddings, clusters = clustering.cluster_and_reduce(embeddings)
# Out:
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_components=5, random_state=42, verbose=True)
# Fri Jul 28 11:57:36 2023 Construct fuzzy simplicial set
# Fri Jul 28 11:57:36 2023 Finding Nearest Neighbors
# Fri Jul 28 11:57:36 2023 Building RP forest with 10 trees
# Fri Jul 28 11:57:37 2023 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# 	 4  /  13
# 	 5  /  13
# 	 6  /  13
# 	Stopping threshold met -- exiting after 6 iterations
# Fri Jul 28 11:57:38 2023 Finished Nearest Neighbor Search
# Fri Jul 28 11:57:39 2023 Construct embedding
# Epochs completed: 100%| ██████████ 200/200 [00:17]
# Fri Jul 28 11:57:56 2023 Finished embedding

# %%
clusters
# Out:
# array([ 50, 117,  87, ...,   4,  -1,  17], dtype=int64)

# %%
clustering.visualize_clusters_dynamic(embeddings, clusters, texts)

# %%
clustering.umap_diagnostics(embeddings)
# Out:
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, random_state=42, verbose=True)
# Fri Jul 28 11:24:05 2023 Construct fuzzy simplicial set
# Fri Jul 28 11:24:05 2023 Finding Nearest Neighbors
# Fri Jul 28 11:24:05 2023 Building RP forest with 10 trees
# Fri Jul 28 11:24:05 2023 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# 	 4  /  13
# 	 5  /  13
# 	 6  /  13
# 	Stopping threshold met -- exiting after 6 iterations
# Fri Jul 28 11:24:07 2023 Finished Nearest Neighbor Search
# Fri Jul 28 11:24:07 2023 Construct embedding
# Epochs completed: 100%| ██████████ 200/200 [00:12]
# Fri Jul 28 11:24:21 2023 Finished embedding
# UMAP Connectivity Plot with Points
# UMAP PCA Diagnostic Plot
# UMAP Local Dimension Diagnostic Plot
# Fri Jul 28 11:24:31 2023 Worst tree score: 0.52159807
# Fri Jul 28 11:24:31 2023 Mean tree score: 0.53513163
# Fri Jul 28 11:24:31 2023 Best tree score: 0.55635892
# ...
