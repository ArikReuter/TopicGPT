# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import inspect

sys.path.insert(0, '../..')

# %%
import os
api_key_openai = os.environ.get('OPENAI_API_KEY')
org_openai = os.environ.get('OPENAI_ORG')

import openai
openai.organization = org_openai
import numpy as np

# %%
from src.TopicRepresentation.TopicRepresentation import Topic
from src.TopwordEnhancement.TopwordEnhancement import TopwordEnhancement

# %%
import numpy as np
import pickle

# %%
twh = TopwordEnhancement(api_key_openai)

# %%
with open("../../Data/SavedTopicRepresentations/Topics_20ng_v1.pkl", "rb") as f:
    topics = pickle.load(f)
# Out:
# Sun Aug  6 16:21:56 2023 Building and compiling search function

# %%
tws = topics[3].top_words["cosine_similarity"][:1000]
tws
# Out:
# ['m/-',
#  'gizwt',
#  'pmfq',
#  'nux',
#  'qtct',
#  'bizw',
#  'isv',
#  'n+b^wm',
#  'mx^-',
#  'expn',
#  'cypherpunks',
#  'cypherpunk',
#  'mc^',
#  'wwhj',
#  't\\/',
#  'ghjn',
#  'zrlk',
#  'jpwu',
#  'cfv',
#  'w-m',
#  'mrlk',
#  'w-s/',
#  'rg/',
#  's=/',
#  'rl\\',
#  'pwe',
#  'nrizwt',
#  'vt\\',
#  'z.lk',
#  'pne',
#  'iq\\',
#  'misc.health.diabetes',
#  'm.ck',
#  'sqm',
#  'w-sv',
#  'z.ck',
#  'oq\\',
#  'mej',
#  'nwk',
#  'w=w',
#  'i.i',
#  'm\\^',
#  'mw=',
#  'x^/c',
#  's\\^',
#  'mwt',
#  't=u',
#  'mnuy',
#  'ballot',
#  'nkjz',
#  'zri',
#  'zv-',
#  'bhi',
#  'zrd',
#  'm=t',
#  'v=gq',
#  'eff.org',
#  'uq\\',
#  'uw=',
#  "s'+",
#  'znb',
#  'first.org',
#  'kleinpaste',
#  'nrizw',
#  'fy+',
#  'vbdi',
#  'kapor',
#  'mqy',
#  'zai',
#  'fql',
#  'cjc',
#  'p\\v',
#  'bhjnuy',
#  'postmaster',
#  'z+sk',
#  'n+bxom',
#  'bizwt',
#  'zrck',
#  'ack',
#  'rg-s',
#  'mt-',
#  'mo\\',
#  'mxte',
#  'sp\\/',
#  'v+-',
#  'oqy',
#  'o.i',
#  'ahmadi',
# ...

# %%
messages=[
    {"role": "system", "content": "You are a helpful assistant. You are excellent at inferring topics from top-words extracted via topic-modelling."},
    {"role": "user", "content": f"Please give me the common topic of those words: {tws}. Also describe the various aspects of the topic. Mention sub-topics and their prevalence if possible. Do NOT cite too many words from the list."},
  ]

twh.count_tokens_api_message(messages)
# Out:
# 4511

# %%
import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=messages,
  temperature = 0.5
)

print(completion.choices[0].message["content"])
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[164], line 5
#       2 import openai
#       3 openai.api_key = os.getenv("OPENAI_API_KEY")
# ----> 5 completion = openai.ChatCompletion.create(
#       6   model="gpt-3.5-turbo",
#       7   messages=messages,
#       8   temperature = 0.5
#       9 )
#      11 print(completion.choices[0].message["content"])
#
# File c:\Users\arik_\anaconda3\envs\llm_sem\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# ...

# %%
completion
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7kYTUs9QkuNjMX4Db9L2JG323kP2R at 0x1eaf1f9ee70> JSON: {
#   "id": "chatcmpl-7kYTUs9QkuNjMX4Db9L2JG323kP2R",
#   "object": "chat.completion",
#   "created": 1691329964,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
print(twh.describe_topic_topwords_completion_object(tws))
# Out:
# 4495
# Too many topwords given. Using only the first part of the topwords that fits into the context length. Number of topwords used:  901
# {
#   "id": "chatcmpl-7kYzdt65IrbBWVtjflO0ITd7zw1M2",
#   "object": "chat.completion",
#   "created": 1691331957,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Based on the provided words, the common topic seems to be related to computer science and technology, specifically focusing on privacy, security, cryptography, and anonymity. \n\nSome of the sub-topics within this topic could include:\n- Cypherpunks and their movement\n- Discussions related to health and diabetes\n- Remailing and anonymous communication\n-"
#       },
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 4027,
#     "completion_tokens": 70,
#     "total_tokens": 4097
#   }
# }
