# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arik_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\arik_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle 
from topicgpt.TopicGPT import TopicGPT

# %%
import os
api_key_openai = os.environ.get('OPENAI_API_KEY2')
#org_openai = os.environ.get('OPENAI_ORG')

# %%
with open("../../Data/Emebeddings/embeddings_20ng_raw.pkl", "rb") as f:
    data_raw = pickle.load(f)

corpus = data_raw["corpus"]
doc_embeddings = data_raw["embeddings"]

with open("../../Data/Emebeddings/embeddings_20ng_vocab.pkl", "rb") as f:
    embeddings_vocab = pickle.load(f)

# %%
tm = TopicGPT(
    openai_api_key = api_key_openai,
    n_topics = 20,
    document_embeddings = doc_embeddings,
    vocab_embeddings = embeddings_vocab
)

# %%
#num_tokens = tm.embedder.compute_number_of_tokens(data)
#print(f"Number of tokens: {num_tokens}")

# %%
tm.fit(corpus)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arik_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\arik_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Computing vocabulary...
# Extracting topics...
# UMAP(angular_rp_forest=True, metric='cosine', min_dist=0, n_components=5, random_state=42, verbose=True)
# Mon Sep  4 18:27:52 2023 Construct fuzzy simplicial set
# Mon Sep  4 18:27:52 2023 Finding Nearest Neighbors
# Mon Sep  4 18:27:52 2023 Building RP forest with 12 trees
# Mon Sep  4 18:27:54 2023 NN descent for 14 iterations
# 	 1  /  14
# 	 2  /  14
# 	 3  /  14
# 	 4  /  14
# 	 5  /  14
# 	 6  /  14
# 	Stopping threshold met -- exiting after 6 iterations
# Mon Sep  4 18:27:58 2023 Finished Nearest Neighbor Search
# Mon Sep  4 18:27:58 2023 Construct embedding
# ...

# %%
tm.topic_lis
# Out:
# [Topic 0: Electronics Equipment Sales,
#  Topic 1: Image Processing,
#  Topic 2: Gun control,
#  Topic 3: Online Privacy and Anonymity,
#  Topic 4: Conflict and Violence.,
#  Topic 5: Computer Hardware,
#  Topic 6: Belief and Atheism,
#  Topic 7: Online Discussions,
#  Topic 8: Computer Software,
#  Topic 9: Car Features and Performance,
#  Topic 10: Encryption and Government,
#  Topic 11: Technology and Computing.,
#  Topic 12: Technology and Computing,
#  Topic 13: Space Exploration,
#  Topic 14: Motorcycle Riding Techniques,
#  Topic 15: Technology,
#  Topic 16: Hockey Games,
#  Topic 17: Health and Medicine.,
#  Topic 18: Baseball games and teams.,
#  Topic 19: Beliefs about Homosexuality.]

# %%
# documents of 13 are about space
tm.topic_lis[13].top_words["cosine_similarity"]
# Out:
# ["n't",
#  'would',
#  'space',
#  'one',
#  'like',
#  'could',
#  'launch',
#  'also',
#  'orbit',
#  'time',
#  'get',
#  'first',
#  'much',
#  'system',
#  'think',
#  'years',
#  'spacecraft',
#  'data',
#  'mission',
#  'know',
#  'people',
#  'may',
#  'satellite',
#  'two',
#  'use',
#  'new',
#  'solar',
#  'see',
#  'program',
#  'planet',
#  'might',
#  'surface',
#  'good',
#  'make',
#  'available',
#  'way',
#  'year',
#  'used',
#  'well',
#  'even',
#  'cost',
#  'information',
#  'back',
#  'atmosphere',
#  'moon',
#  'lunar',
#  'around',
#  'power',
#  'something',
#  'satellites',
#  'need',
#  'still',
#  'enough',
#  'work',
#  'shuttle',
#  'many',
#  'energy',
#  'light',
#  'part',
#  'idea',
#  'small',
#  'long',
#  'want',
#  'large',
#  'world',
#  'going',
#  'missions',
#  'made',
#  'degrees',
#  'sky',
#  'problem',
#  'things',
#  'high',
#  'since',
#  'using',
#  'money',
#  'etc',
#  'station',
#  'systems',
#  'mass',
#  'probably',
#  'put',
# ...

# %%
tm.topic_lis[13].top_words["cosine_similarity"]
# Out:
# ["n't",
#  'would',
#  'space',
#  'one',
#  'like',
#  'could',
#  'launch',
#  'also',
#  'orbit',
#  'time',
#  'get',
#  'first',
#  'much',
#  'system',
#  'think',
#  'years',
#  'spacecraft',
#  'data',
#  'mission',
#  'know',
#  'people',
#  'may',
#  'satellite',
#  'two',
#  'use',
#  'new',
#  'solar',
#  'see',
#  'program',
#  'planet',
#  'might',
#  'surface',
#  'good',
#  'make',
#  'available',
#  'way',
#  'year',
#  'used',
#  'well',
#  'even',
#  'cost',
#  'information',
#  'back',
#  'atmosphere',
#  'moon',
#  'lunar',
#  'around',
#  'power',
#  'something',
#  'satellites',
#  'need',
#  'still',
#  'enough',
#  'work',
#  'shuttle',
#  'many',
#  'energy',
#  'light',
#  'part',
#  'idea',
#  'small',
#  'long',
#  'want',
#  'large',
#  'world',
#  'going',
#  'missions',
#  'made',
#  'degrees',
#  'sky',
#  'problem',
#  'things',
#  'high',
#  'since',
#  'using',
#  'money',
#  'etc',
#  'station',
#  'systems',
#  'mass',
#  'probably',
#  'put',
# ...

# %%
tm.topic_lis[13].documents
# Out:
# ['How difficult would it be to do a solar sail mission to say mercury?  Not much has been there and there is a 23?KM/s delta v to eat off.  could a  solar sail, handle say adiscovery bus, and drop it into mercury orbit,  good enough for rockets to put it into some form of polar orbit?',
#  ' You\'re assuming that "go solar" = "photovoltaic".  Solar dynamic power (turbo-alternators) doesn\'t have this problem.  It also has rather less air drag due to its higher efficiency, which is a non-trivial win for big solar plants at low altitude.  Now, you might have to replace the *rest* of the electronics fairly often, unless you invest substantial amounts of mass in shielding.   References?  Such treaties have been *proposed*, but as far as I know, none of them has ever been negotiated or signed.',
# ...

# %%
tm.visualize_clusters()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tm.visualize_clusters()
#
# File c:\Users\arik_\Documents\Dokumente\Studium\Master\LLM_seminar\Project\src\TopicGPT\TopicGPT.py:217, in TopicGPT.visualize_clusters(self)
#     214 all_document_indices = np.concatenate([np.repeat(i, topic.document_embeddings_hd.shape[0]) for i, topic in enumerate(self.topic_lis)], axis = 0)
#     215 class_names = [str(topic) for topic in self.topic_lis]
# --> 217 self.clusterer.visualize_clusters_dynamic(all_document_embeddings, all_document_indices, all_texts, class_names)
#
# File c:\Users\arik_\Documents\Dokumente\Studium\Master\LLM_seminar\Project\src\Clustering\Clustering.py:189, in Clustering_and_DimRed.visualize_clusters_dynamic(self, embeddings, labels, texts, class_names)
#     187 # Reduce dimensionality with UMAP
# ...

# %%
tm.print_topics()
# Out:
# Topic 0: Technology
#
# Topic_description: The common topic of the given words is "Plants and Botany".
#
# Aspects and sub-topics of this topic include:
# 1. Plant variety and abundance: "plenty", "plentiful", "plethora"
# 2. Pleasure and enjoyment derived from plants: "pleasures", "pleasure", "pleasing"
# 3. Plant-related activities: "planting", "planted", "planters"
# 4. Planning and organization related to plants: "plans", "planning", "planners"
# 5. Plant structures and characteristics: "plumbing", "plugs", "plank", "plastic", "plasma"
# Top words: ['a.a', 'plesetsk', 'plenty', 'plentiful', 'pledged', 'pledge', 'pleasures', 'pleasure', 'pleasing', 'pleases']
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Topic 1: Electronics Equipment
#
# ...

# %%
tm
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\arik_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\arik_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# TopicGPT object with the following parameters:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# n_topics: 20
# openai_prompting_model: gpt-3.5-turbo-16k
# max_number_of_tokens: 16384
# corpus_instruction:
# embedding_model: text-embedding-ada-002
# clusterer: <Clustering.Clustering.Clustering_and_DimRed object at 0x000001EA20899910>
# n_topwords: 2000
# n_topwords_description: 500
# topword_extraction_methods: ['tfidf', 'cosine_similarity']
# compute_vocab_hyperparams: {}
# enhancer: TopwordEnhancement(openai_model = gpt-3.5-turbo-16k)
# ...

# %%
tm.topic_lis
# Out:
# [Topic 0: Electronics Equipment,
#  Topic 1: Image Processing,
#  Topic 2: Gun Control,
#  Topic 3: Internet Privacy,
#  Topic 4: Conflict and Violence,
#  Topic 5: Computer Hardware,
#  Topic 6: Beliefs and Arguments,
#  Topic 7: Online Discussions,
#  Topic 8: Computer Software,
#  Topic 9: Car Features and Performance,
#  Topic 10: Encryption and Security,
#  Topic 11: Technology and Computing,
#  Topic 12: Technology and Computing,
#  Topic 13: Space Exploration,
#  Topic 14: Motorcycle Riding,
#  Topic 15: Technology and Computing,
#  Topic 16: Hockey games and teams.,
#  Topic 17: Healthcare and Medical Research,
#  Topic 18: Baseball performance,
#  Topic 19: Religious beliefs and homosexuality.]

# %%
with open("../../Data/SavedTopicRepresentations/TopicGPT_20ng.pkl", "wb") as f:
    pickle.dump(tm, f)

# %%
with open("../../Data/SavedTopicRepresentations/TopicGPT_20ng_topics.pkl", "wb") as f:
    pickle.dump(tm.topic_lis, f)

# %%
tm.pprompt("Please split topic 0 into subtopics. Identify the number of subtopics automatically.")
# Out:
# GPT wants to the call the function:  {
#   "name": "split_topic_hdbscan",
#   "arguments": "{\n  \"topic_idx\": 0\n}"
# }
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:00<00:00, 37.04it/s]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# 100%|██████████| 1/1 [00:04<00:00,  4.75s/it]
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:00<00:00, 31.29it/s]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# 100%|██████████| 1/1 [00:03<00:00,  3.74s/it]
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:00<00:00, 57.08it/s]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# 100%|██████████| 1/1 [00:05<00:00,  5.09s/it]
# ...

# %%
tm.pprompt("Please split topic 1 into three subtopics. Do this inplace")
# Out:
# GPT wants to the call the function:  {
#   "name": "split_topic_kmeans",
#   "arguments": "{\n  \"topic_idx\": 1,\n  \"n_clusters\": 3,\n  \"inplace\": true\n}"
# }
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:00<00:00, 16.44it/s]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Epochs completed: 100%| ██████████ 100/100 [00:02]
#   0%|          | 0/1 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 tm.pprompt("Please split topic 1 into three subtopics. Do this inplace")
#
# File c:\Users\arik_\Documents\Dokumente\Studium\Master\LLM_seminar\Project\src\TopicGPT\TopicGPT.py:258, in TopicGPT.pprompt(self, query, return_function_result)
#     248 def pprompt(self, query:str, return_function_result: bool = True) -> object:
#     249     """
# ...

# %%
tm.pprompt("")

# %%
tm.topic_lis
# Out:
# [Topic 0: Technology and Computing,
#  Topic 1: Image Processing,
#  Topic 2: Gun control,
#  Topic 3: Online Privacy,
#  Topic 4: Conflict and Violence,
#  Topic 5: Computer Hardware,
#  Topic 6: Belief in God,
#  Topic 7: Online Discussions,
#  Topic 8: Computer Software,
#  Topic 9: Car Features and Performance.,
#  Topic 10: Computer Hardware,
#  Topic 11: Technology and Computing,
#  Topic 12: Technology,
#  Topic 13: Space Exploration,
#  Topic 14: Motorcycle Riding Techniques,
#  Topic 15: Technology,
#  Topic 16: Hockey games and teams,
#  Topic 17: Healthcare and Medicine,
#  Topic 18: Baseball Games,
#  Topic 19: Computer Hacking,
#  Topic 20: Graphical User Interface (GUI),
#  Topic 21: Image Processing]

# %%
r1 = tm.pprompt("Please combine topics 19 , 20 and 21 into a single topic. Do this inplace")
# Out:
# {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "combine_topics",
#     "arguments": "{\n  \"topic_idx_lis\": [19, 20, 21],\n  \"inplace\": true\n}"
#   }
# }
# GPT wants to the call the function:  {
#   "name": "combine_topics",
#   "arguments": "{\n  \"topic_idx_lis\": [19, 20, 21],\n  \"inplace\": true\n}"
# }
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:03<00:00,  3.84s/it]
# Epochs completed: 100%| ██████████ 30/30 [00:01]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# 100%|██████████| 1/1 [00:06<00:00,  6.86s/it]
# [Topic 0: Technology and Computing
# , Topic 1: Image Processing
# , Topic 2: Gun control
# , Topic 3: Online Privacy
# , Topic 4: Conflict and Violence
# , Topic 5: Computer Hardware
# , Topic 6: Belief in God
# , Topic 7: Online Discussions
# , Topic 8: Computer Software
# , Topic 9: Car Features and Performance.
# , Topic 10: Computer Hardware
# ...

# %%
tm.topic_lis
# Out:
# [Topic 0: Electronics Equipment,
#  Topic 1: Gun control,
#  Topic 2: Internet Privacy,
#  Topic 3: Conflict and violence,
#  Topic 4: Computer Hardware,
#  Topic 5: Beliefs and Arguments,
#  Topic 6: Online Discussions,
#  Topic 7: Computer Software,
#  Topic 8: Car Features,
#  Topic 9: Encryption and Government,
#  Topic 10: Technology and Computing,
#  Topic 11: Technology and Computing,
#  Topic 12: Space Exploration,
#  Topic 13: Motorcycle riding techniques,
#  Topic 14: Technology and Computing,
#  Topic 15: Hockey games,
#  Topic 16: Healthcare and Medical Research,
#  Topic 17: Baseball Games,
#  Topic 18: Beliefs about homosexuality,
#  Topic 19: Image Processing,
#  Topic 20: Public Policy,
#  Topic 21: Gun Control]

# %%
r1 = tm.pprompt("Please combine topics 20 and 21. Do this inplace")
# Out:
# GPT wants to the call the function:  {
#   "name": "combine_topics",
#   "arguments": "{\n  \"topic_idx_lis\": [20, 21],\n  \"inplace\": true\n}"
# }
# Epochs completed: 100%| ██████████ 100/100 [00:02]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]
# Epochs completed: 100%| ██████████ 30/30 [00:06]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# 100%|██████████| 1/1 [00:15<00:00, 15.30s/it]
# result in prompt of TopicGPT: ([<OpenAIObject at 0x16b2a9476b0> JSON: {
#   "role": "assistant",
#   "content": null,
#   "function_call": {
#     "name": "combine_topics",
#     "arguments": "{\n  \"topic_idx_lis\": [20, 21],\n  \"inplace\": true\n}"
#   }
# }, <OpenAIObject chat.completion id=chatcmpl-7txD5FxnjxcTDL1bN7XKulRQy4PT3 at 0x16b59eb0890> JSON: {
#   "id": "chatcmpl-7txD5FxnjxcTDL1bN7XKulRQy4PT3",
#   "object": "chat.completion",
#   "created": 1693569999,
#   "model": "gpt-3.5-turbo-16k-0613",
#   "choices": [
#     {
#       "index": 0,
# ...

# %%
r1
# Out:
# [Topic 0: Electronics Equipment,
#  Topic 1: Gun control,
#  Topic 2: Internet Privacy,
#  Topic 3: Conflict and violence,
#  Topic 4: Computer Hardware,
#  Topic 5: Beliefs and Arguments,
#  Topic 6: Online Discussions,
#  Topic 7: Computer Software,
#  Topic 8: Car Features,
#  Topic 9: Encryption and Government,
#  Topic 10: Technology and Computing,
#  Topic 11: Technology and Computing,
#  Topic 12: Space Exploration,
#  Topic 13: Motorcycle riding techniques,
#  Topic 14: Technology and Computing,
#  Topic 15: Hockey games,
#  Topic 16: Healthcare and Medical Research,
#  Topic 17: Baseball Games,
#  Topic 18: Beliefs about homosexuality,
#  Topic 19: Image Processing,
#  Topic 20: Public Policy,
#  Topic 21: Gun Control,
#  Topic 20: government policies and public opinion]

# %%
tm.topic_lis
# Out:
# [Topic 0: Electronics Equipment,
#  Topic 1: Gun control,
#  Topic 2: Internet Privacy,
#  Topic 3: Conflict and violence,
#  Topic 4: Computer Hardware,
#  Topic 5: Beliefs and Arguments,
#  Topic 6: Online Discussions,
#  Topic 7: Computer Software,
#  Topic 8: Car Features,
#  Topic 9: Encryption and Government,
#  Topic 10: Technology and Computing,
#  Topic 11: Technology and Computing,
#  Topic 12: Space Exploration,
#  Topic 13: Motorcycle riding techniques,
#  Topic 14: Technology and Computing,
#  Topic 15: Hockey games,
#  Topic 16: Healthcare and Medical Research,
#  Topic 17: Baseball Games,
#  Topic 18: Beliefs about homosexuality,
#  Topic 19: Image Processing,
#  Topic 20: government policies and public opinion]

# %%
tm.pprompt("Please split topic 0 into subtopics. Do this inplace")
# Out:
# GPT wants to the call the function:  {
#   "name": "split_topic_kmeans",
#   "arguments": "{\n  \"topic_idx\": 0,\n  \"inplace\": true\n}"
# }
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:02<00:00,  2.54s/it]
# Epochs completed: 100%| ██████████ 100/100 [00:01]
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# 100%|██████████| 1/1 [00:05<00:00,  5.30s/it]
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# Computing word-topic matrix: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
# Epochs completed: 100%| ██████████ 100/100 [00:02]
# Epochs completed: 100%| ██████████ 100/100 [00:00]
# 100%|██████████| 1/1 [00:04<00:00,  4.46s/it]
# I have split topic 0 into two subtopics based on the provided words. Here are the new subtopics:
#
# 1. Subtopic 1: Email Communication
#    - This subtopic revolves around the theme of "communication and information exchange."
# ...

# %%
tm.topic_lis
# Out:
# [Topic 0: Conflict and violence,
#  Topic 1: Computer Hardware,
#  Topic 2: Beliefs and Arguments,
#  Topic 3: Online Discussions,
#  Topic 4: Computer Software,
#  Topic 5: Car Features,
#  Topic 6: Encryption and Government,
#  Topic 7: Technology and Computing,
#  Topic 8: Technology and Computing,
#  Topic 9: Space Exploration,
#  Topic 10: Motorcycle riding techniques,
#  Topic 11: Technology and Computing,
#  Topic 12: Hockey games,
#  Topic 13: Healthcare and Medical Research,
#  Topic 14: Baseball Games,
#  Topic 15: Beliefs about homosexuality,
#  Topic 16: Image Processing,
#  Topic 17: government policies and public opinion,
#  Topic 18: Electronics for Sale,
#  Topic 19: Telephone Systems,
#  Topic 20: Government Raid on Compound,
#  Topic 21: Gun control,
#  Topic 22: Email Communication,
#  Topic 23: Internet Privacy]

# %%
r = tm.pprompt("please compare topics 7 and 8.")
# Out:
# GPT wants to the call the function:  {
#   "name": "get_topic_information",
#   "arguments": "{\n  \"topic_idx_lis\": [7, 8]\n}"
# }
# Topic 7 is about Technology and Computing. It includes sub-topics such as pledges and pleas, pleasure and satisfaction, play and entertainment, plumbing and construction, and plotting and visualization. Some of the top words associated with this topic are "plenty", "pleased", "playmates", "plumbing", and "plotting".
#
# Topic 8 is also about Technology and Computing, specifically focusing on plants and planting. Sub-topics within this topic include pleasure and pleasing, play and playoffs, plumbing and plugs, planets and planetary, and polishing and polished. Some of the top words associated with this topic are "plenty", "pleasures", "playmates", "plumbing", and "planets".
#
# Both topics seem to have some overlap in terms of the sub-topics they cover. The main difference might be the emphasis on plants and planting in topic 8.
